# %%
import matplotlib.pyplot as plt
import numpy as np

results_TM = [[227, 189, 270, 233], [228, 188, 272, 231], [246, 207, 289, 251], [255, 216, 299, 259], [255, 217, 298, 261], [251, 209, 295, 252], [251, 209, 294, 253], [251, 210, 295, 253], [251, 224, 294, 268], [251, 212, 295, 255], [252, 214, 295, 258], [252, 207, 296, 250], [252, 207, 295, 251], [252, 207, 296, 250], [252, 208, 295, 252], [252, 209, 296, 252], [251, 225, 294, 269], [251, 232, 295, 275], [251, 232, 294, 276], [251, 232, 295, 275], [251, 231, 294, 275], [252, 231, 296, 274], [253, 233, 296, 277]]
center = []
for i in range(len(results_TM)):
    center_x =  (results_TM[i][0] + results_TM[i][2])/2
    center_y =  (results_TM[i][1] + results_TM[i][3])/2
    center.append([center_x,center_y])
center = np.array(center)

fig,ax = plt.subplots(2,1,figsize=(15,7),tight_layout=True)
ax[0].plot(center[:,0])
#ax[0].plot(center_yolo[:,0])
ax[0].set_title("X")
ax[1].plot(center[:,1])
#ax[1].plot(center_yolo[:,1])
ax[1].set_title("Y")
fig.savefig("result.jpg")
